# %%
# Chat GPT css style

from IPython.core.display import HTML

HTML('''
<style>
/* Itt a fenti CSS jöhet beillesztve */

/* --- Alap stílus --- */
body, .rendered_html {
    font-family: 'Segoe UI', 'Helvetica Neue', 'Helvetica', 'Arial', sans-serif;
    // font-size: 16px;
    font-size: 14px;
    line-height: 1.6;
    color: #1f1f1f;
    // background-color: #f9f9f9;
}

/* --- Címsorok --- */
.rendered_html h1 {
    font-size: 2em;
    border-bottom: 2px solid #ddd;
    padding-bottom: 0.3em;
    margin-top: 1.2em;
}
.rendered_html h2 {
    font-size: 1.6em;
    margin-top: 1em;
}
.rendered_html h3 {
    font-size: 1.3em;
    margin-top: 0.8em;
}

/* --- Kódblokkok (Markdown output) --- */
.rendered_html pre, .rendered_html code {
    background: #2d2d2d;
    color: #f8f8f2;
    padding: 0.5em;
    border-radius: 6px;
    font-family: Consolas, 'Courier New', monospace;
    font-size: 0.95em;
}

/* --- Inline code --- */
.rendered_html code {
    padding: 2px 6px;
}

/* --- Listák --- */
.rendered_html ul, .rendered_html ol {
    padding-left: 2em;
}

/* --- Táblázatok --- */
.rendered_html table {
    border-collapse: collapse;
    width: 100%;
    margin: 1em 0;
}
.rendered_html th, .rendered_html td {
    border: 1px solid #ccc;
    padding: 8px;
    text-align: left;
}
.rendered_html th {
    background-color: #eee;
}

/* --- Kiemelt idézetek (blockquote) --- */
.rendered_html blockquote {
    border-left: 4px solid #ccc;
    padding-left: 1em;
    color: #666;
    margin: 1em 0;
}

/* --- Linkek --- */
.rendered_html a {
    color: #2a7ae2;
    text-decoration: none;
}
.rendered_html a:hover {
    text-decoration: underline;
}

</style>
''')
# Out:
# <style>
# /* Itt a fenti CSS jöhet beillesztve */
#
# /* --- Alap stílus --- */
# body, .rendered_html {
#     font-family: 'Segoe UI', 'Helvetica Neue', 'Helvetica', 'Arial', sans-serif;
#     // font-size: 16px;
#     font-size: 14px;
#     line-height: 1.6;
#     color: #1f1f1f;
#     // background-color: #f9f9f9;
# }
#
# /* --- Címsorok --- */
# .rendered_html h1 {
#     font-size: 2em;
#     border-bottom: 2px solid #ddd;
#     padding-bottom: 0.3em;
#     margin-top: 1.2em;
# }
# .rendered_html h2 {
#     font-size: 1.6em;
#     margin-top: 1em;
# }
# .rendered_html h3 {
#     font-size: 1.3em;
#     margin-top: 0.8em;
# }
#
# /* --- Kódblokkok (Markdown output) --- */
# .rendered_html pre, .rendered_html code {
#     background: #2d2d2d;
#     color: #f8f8f2;
#     padding: 0.5em;
#     border-radius: 6px;
#     font-family: Consolas, 'Courier New', monospace;
#     font-size: 0.95em;
# }
#
# /* --- Inline code --- */
# .rendered_html code {
#     padding: 2px 6px;
# }
#
# ...

# %% [markdown]
# # Ez egy template magamnak ha jegyzetelni akarok.
#
# Hasznos formázásokkal van tele.
