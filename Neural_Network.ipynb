# %% [markdown]
# <a href="https://colab.research.google.com/github/JoDeMiro/Micado-Research/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MLPRegressor
#
# Különböző beállításokkal,
#
# Baromira nem mindegy, hogy milyen beállításokat használunk, néha ezek hatására képtelen tanulni.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
x = np.arange(0, 600, 1)

y = np.sin(x/180) + np.sin(x/60)

x = x.reshape(-1,1)
y = y

# %% [markdown]
# ## Tanh

# %%
mlp = MLPRegressor(hidden_layer_sizes=(3, ),
                   activation='tanh', 
                   solver='sgd',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

# %% [markdown]
# ## Ilyen a story ha az x nincs normalizálva
#
# A bement tarománya 0-600

# %%
mlp.fit(x, y)
predicted = mlp.predict(x)
plt.scatter(x, y)
plt.plot(x, predicted, c='black')
plt.show()

# %% [markdown]
# ## Ilyen az amikor x és y 0,1 közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(0,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(0,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  0.0
# xs1.max =  1.0
# ys1.min =  0.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Ilyen az amikor x (-1,1) közé y (0,1) közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(0,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  0.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Ilyen az amikor x (0,1) és y (-1,1) közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(0,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  0.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Ilyen az amikor x és y is (-1,1) közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Tehát a fentiekből láthattuk,
#
# #### Hogy 'tanh' aktivációs függvény esetén az a jó, ha x és y is **(-1,1)** közé van normalizálva. Minden más eset rossz.

# %% [markdown]
# ## Logistic

# %%
mlp = MLPRegressor(hidden_layer_sizes=(3, ),
                   activation='logistic', 
                   solver='sgd',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

# %% [markdown]
# ## Ilyen a story ha az x nincs normalizálva
#
# A bement tarománya 0-600

# %%
mlp.fit(x, y)
predicted = mlp.predict(x)
plt.scatter(x, y)
plt.plot(x, predicted, c='black')
plt.show()

# %% [markdown]
# ## Ilyen az amikor x és y 0,1 közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(0,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(0,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  0.0
# xs1.max =  1.0
# ys1.min =  0.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Ilyen az amikor x (-1,1) közé y (0,1) közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(0,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  0.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Ilyen az amikor x (0,1) és y (-1,1) közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(0,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  0.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Ilyen az amikor x és y is (-1,1) közé van normalizálva

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Tehát a fentiekből az látszik
#
# #### Hogy a 'logistic' esetében nem képes megtalálni a megfelelő összefüggést.
#
# Azonban alább elvégeztem a következő kísérletet és az derült ki,<br>
# hogy az 'sgd' optimizer nem volt képes megtalálni az összefüggést.<br>
# Ha az optimizer 'adam' akkor a ha mindkét változót (-1,1) tartományba<br>
# normalizálom, akkor szintén jó megoldás születik.
#
# Ebből azt a következtetést vonom le, hogy 'logistic' esetén is az a célravezető<br>
# ha mindkét válotzót a (-1,1) tartományba transzformálom.
#
# ## Logistic átviteli függvény Adam optimizerrel x és y (-1,1) közé transzformálva

# %%
mlp = MLPRegressor(hidden_layer_sizes=(3, ),
                   activation='logistic', 
                   solver='adam',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Logistic átviteli függvény Adam optimizerrel x és y (0,1) közé transzformálva
#
# sajnos, ha nem transformálom -1, 1 közé az értékeket akkor ez sem működik

# %%
mlp = MLPRegressor(hidden_layer_sizes=(3,),
                   activation='logistic', 
                   solver='adam',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

scaler_x_one = MinMaxScaler(feature_range=(0,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(0,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  0.0
# xs1.max =  1.0
# ys1.min =  0.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Logistic átviteli függvény Adam optimizerrel x és y (-1,1) közé transzformálva
#
# ha transformálom -1, 1 közé az értékeket akkor ez az átviteli függvény is működik, tehát alapvetően nem az átviteli függvényben van a különbség, hanem a transzformációban és az optimizerben.

# %%
mlp = MLPRegressor(hidden_layer_sizes=(3,),
                   activation='logistic', 
                   solver='adam',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## Logistic átviteli függvény Adam optimizerrel x és y (-1,1) közé transzformálva
#
# ha transformálom -1, 1 közé az értékeket akkor ez az átviteli függvény is működik, tehát alapvetően nem az átviteli függvényben van a különbség, hanem a transzformációban és az optimizerben.
#
# Ugyanakkor összetettebb neurális háló estén 'adam' optimizer képes (0,1) közé transzformált értékekel is megtalálni a megfelelő megoldást<br>
#
# Persze nem olyan jól, mintha (-1,1) közé lenne minden transzformálva.

# %%
mlp = MLPRegressor(hidden_layer_sizes=(10, 5),
                   activation='logistic', 
                   solver='adam',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

scaler_x_one = MinMaxScaler(feature_range=(0,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(0,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  0.0
# xs1.max =  1.0
# ys1.min =  0.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %%
mlp = MLPRegressor(hidden_layer_sizes=(10, 5),
                   activation='logistic', 
                   solver='adam',
                   batch_size='auto',
                   learning_rate_init=0.01,
                   max_iter=2000,
                   shuffle=False,
                   random_state=1,
                   momentum=0.9,
                   nesterovs_momentum=True,
                   early_stopping=True,
                   n_iter_no_change=2000)

scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1
mlp.fit(x_scaled, y_scaled)
predicted = mlp.predict(x_scaled)
plt.scatter(x_scaled, y_scaled)
plt.plot(x_scaled, predicted, c='black')
plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)

# %% [markdown]
# ## A tanulság amit ebből levonni lehet
#
# 1. használjunk 'adam' opmtimizert
# 2. mindíg transzformáljuk a bemenő változókat (-1,1) közé
# 3. mindíg transzformáljuk a kimenő változót (-1,1) közé
# 4. használjuk a 'tahn' átviteli függvényt
# 5. figyeljünk arra, hogy össze legyenek rázva az adatok

# %% [markdown]
# ## Bemutató

# %%
y.max()
# Out:
# 1.5395942123775428

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1


for i in range(0, 200, 20):
  print('#i = ', i)
  if( i != 0 ):
    mlp = MLPRegressor(hidden_layer_sizes=(10, 5),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.01,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)

    mlp.fit(x_scaled, y_scaled)
    predicted = mlp.predict(x_scaled)
    plt.scatter(x_scaled, y_scaled)
    plt.plot(x_scaled, predicted, c='black')
    plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)
# #i =  0
# #i =  20
# #i =  40
# #i =  60
# #i =  80
# #i =  100
# #i =  120
# #i =  140
# #i =  160
# #i =  180

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1


for i in range(0, 500, 50):
  print('#i = ', i)
  if( i != 0 ):
    mlp1 = MLPRegressor(hidden_layer_sizes=(10, 5),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.01,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp2 = MLPRegressor(hidden_layer_sizes=(3,),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.01,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)

    mlp1.fit(x_scaled, y_scaled)
    predicted1 = mlp1.predict(x_scaled)

    mlp2.fit(x_scaled, y_scaled)
    predicted2 = mlp2.predict(x_scaled)

    fig, ax = plt.subplots(1,2, figsize=(10,4))
    ax[0].scatter(x_scaled, y_scaled)
    ax[0].plot(x_scaled, predicted1, c='black')
    ax[1].scatter(x_scaled, y_scaled)
    ax[1].plot(x_scaled, predicted2, c='black')
    plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)
# #i =  0
# #i =  50
# #i =  100
# #i =  150
# #i =  200
# #i =  250
# #i =  300
# #i =  350
# #i =  400
# #i =  450

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1


for i in range(0, 200, 20):
  print('#i = ', i)
  if( i != 0 ):
    mlp1 = MLPRegressor(hidden_layer_sizes=(10, 5),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.02,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp2 = MLPRegressor(hidden_layer_sizes=(10, 5),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.01,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)

    mlp1.fit(x_scaled, y_scaled)
    predicted1 = mlp1.predict(x_scaled)

    mlp2.fit(x_scaled, y_scaled)
    predicted2 = mlp2.predict(x_scaled)

    fig, ax = plt.subplots(1,2, figsize=(10,4))
    ax[0].scatter(x_scaled, y_scaled)
    ax[0].plot(x_scaled, predicted1, c='red')
    ax[1].scatter(x_scaled, y_scaled)
    ax[1].plot(x_scaled, predicted2, c='black')
    plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)
# #i =  0
# #i =  20
# #i =  40
# #i =  60
# #i =  80
# #i =  100
# #i =  120
# #i =  140
# #i =  160
# #i =  180

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1


for i in range(0, 30, 1):
  print('#i = ', i)
  if( i != 0 ):
    mlp1 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='relu', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.02,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp2 = MLPRegressor(hidden_layer_sizes=(10, 5),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.02,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)

    mlp1.fit(x_scaled, y_scaled)
    predicted1 = mlp1.predict(x_scaled)

    mlp2.fit(x_scaled, y_scaled)
    predicted2 = mlp2.predict(x_scaled)

    fig, ax = plt.subplots(1,2, figsize=(10,4))
    ax[0].scatter(x_scaled, y_scaled)
    ax[0].plot(x_scaled, predicted1, c='red')
    ax[1].scatter(x_scaled, y_scaled)
    ax[1].plot(x_scaled, predicted2, c='black')
    plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)
# #i =  0
# #i =  1
# #i =  2
# #i =  3
# #i =  4
# #i =  5
# #i =  6
# #i =  7
# #i =  8
# #i =  9
# #i =  10
# #i =  11
# #i =  12
# #i =  13
# #i =  14
# #i =  15
# #i =  16
# #i =  17
# #i =  18
# #i =  19
# #i =  20
# #i =  21
# #i =  22
# #i =  23
# #i =  24
# #i =  25
# #i =  26
# #i =  27
# #i =  28
# #i =  29

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1


for i in range(0, 30, 2):
  print('#i = ', i)
  if( i != 0 ):
    mlp1 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='relu', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.01,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp2 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='relu', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.02,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp3 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='relu', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.03,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)

    mlp1.fit(x_scaled, y_scaled)
    predicted1 = mlp1.predict(x_scaled)

    mlp2.fit(x_scaled, y_scaled)
    predicted2 = mlp2.predict(x_scaled)

    mlp3.fit(x_scaled, y_scaled)
    predicted3 = mlp3.predict(x_scaled)

    fig, ax = plt.subplots(1,3, figsize=(15,4), sharey=True)
    ax[0].scatter(x_scaled, y_scaled)
    ax[0].plot(x_scaled, predicted1, c='red')
    ax[1].scatter(x_scaled, y_scaled)
    ax[1].plot(x_scaled, predicted2, c='black')
    ax[2].scatter(x_scaled, y_scaled)
    ax[2].plot(x_scaled, predicted3, c='orange')
    plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)
# #i =  0
# #i =  2
# #i =  4
# #i =  6
# #i =  8
# #i =  10
# #i =  12
# #i =  14
# #i =  16
# #i =  18
# #i =  20
# #i =  22
# #i =  24
# #i =  26
# #i =  28

# %%
scaler_x_one = MinMaxScaler(feature_range=(-1,1))
scaler_x_one.fit(x)
xs1 = scaler_x_one.transform(x)
scaler_y_one = MinMaxScaler(feature_range=(-1,1))
scaler_y_one.fit(y.reshape(-1,1))
ys1 = scaler_y_one.transform(y.reshape(-1,1))
print('xs1.min = ', xs1.min())
print('xs1.max = ', xs1.max())
print('ys1.min = ', ys1.min())
print('ys1.max = ', ys1.max())
print('ys1.shape = ', ys1.shape)
x_scaled = xs1
y_scaled = ys1


for i in range(0, 30, 1):
  print('#i = ', i)
  if( i != 0 ):
    mlp1 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.01,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp2 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.02,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)
    
    mlp3 = MLPRegressor(hidden_layer_sizes=(30, 15),
                      activation='tanh', 
                      solver='adam',
                      batch_size='auto',
                      learning_rate_init=0.03,
                      max_iter=i,
                      shuffle=True,
                      random_state=1,
                      momentum=0.9,
                      nesterovs_momentum=True,
                      early_stopping=True,
                      n_iter_no_change=2000)

    mlp1.fit(x_scaled, y_scaled)
    predicted1 = mlp1.predict(x_scaled)

    mlp2.fit(x_scaled, y_scaled)
    predicted2 = mlp2.predict(x_scaled)

    mlp3.fit(x_scaled, y_scaled)
    predicted3 = mlp3.predict(x_scaled)

    fig, ax = plt.subplots(1,3, figsize=(15,4), sharey=True)
    ax[0].scatter(x_scaled, y_scaled)
    ax[0].plot(x_scaled, predicted1, c='red')
    ax[1].scatter(x_scaled, y_scaled)
    ax[1].plot(x_scaled, predicted2, c='black')
    ax[2].scatter(x_scaled, y_scaled)
    ax[2].plot(x_scaled, predicted3, c='orange')
    plt.show()
# Out:
# xs1.min =  -1.0
# xs1.max =  1.0
# ys1.min =  -1.0
# ys1.max =  1.0
# ys1.shape =  (600, 1)
# #i =  0
# #i =  1
# #i =  2
# #i =  3
# #i =  4
# #i =  5
# #i =  6
# #i =  7
# #i =  8
# #i =  9
# #i =  10
# #i =  11
# #i =  12
# #i =  13
# #i =  14
# #i =  15
# #i =  16
# #i =  17
# #i =  18
# #i =  19
# #i =  20
# #i =  21
# #i =  22
# #i =  23
# #i =  24
# #i =  25
# #i =  26
# #i =  27
# #i =  28
# #i =  29
